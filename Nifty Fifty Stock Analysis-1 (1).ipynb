# %% [markdown]
# # Nifty Fifty Stock Analysis

# %% [markdown]
# # Introduction

# %% [markdown]
# #### This Data sets include information about the Nifty Fifty stocks in National Stock Exchange market in India and I choose the Adani Ports stock and Explore the analysis using matplotlip and seaborn library

# %%
#Import all the dependecies in this project

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
color_pal = sns.color_palette()
import warnings

# %%
#Read the dataset
stock=pd.read_csv('ADANIPORTS.csv')

# %%
#view the dataset
stock
# Out:
#             Date      Symbol Series  Prev Close     Open     High      Low  \
# 0     01-01-2008  MUNDRAPORT     EQ     1268.80  1279.00  1319.00  1263.70
# 1     02-01-2008  MUNDRAPORT     EQ     1296.85  1310.25  1324.00  1270.00
# 2     03-01-2008  MUNDRAPORT     EQ     1307.45  1305.00  1314.70  1261.15
# 3     04-01-2008  MUNDRAPORT     EQ     1275.80  1278.80  1294.80  1233.00
# 4     07-01-2008  MUNDRAPORT     EQ     1240.35  1240.00  1278.90  1215.00
# ...          ...         ...    ...         ...      ...      ...      ...
# 3294  26-04-2021  ADANIPORTS     EQ      725.35   733.00   739.65   728.90
# 3295  27-04-2021  ADANIPORTS     EQ      730.75   735.00   757.50   727.35
# 3296  28-04-2021  ADANIPORTS     EQ      749.15   755.00   760.00   741.10
# 3297  29-04-2021  ADANIPORTS     EQ      746.25   753.20   765.85   743.40
# 3298  30-04-2021  ADANIPORTS     EQ      746.75   739.00   759.45   724.50
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# 0     1308.00  1296.85  1285.72    491348  6.317350e+13       NaN
# 1     1300.15  1307.45  1302.15    703815  9.164730e+13       NaN
# 2     1267.15  1275.80  1289.24    505058  6.511430e+13       NaN
# 3     1239.90  1240.35  1256.03    550795  6.918170e+13       NaN
# 4     1233.00  1227.25  1244.76    630963  7.853980e+13       NaN
# ...       ...      ...      ...       ...           ...       ...
# 3294   729.20   730.75   733.25   9390549  6.885660e+14  116457.0
# 3295   748.60   749.15   747.67  20573107  1.538190e+15  236896.0
# 3296   743.40   746.25   751.02  11156977  8.379110e+14  130847.0
# 3297   746.40   746.75   753.06  13851910  1.043140e+15  153293.0
# 3298   726.40   730.05   743.35  12600934  9.366910e+14  132141.0
#
#       Deliverable Volume  %Deliverble     M.Y
# 0                 172911       0.3519  Jan-08
# 1                 221397       0.3146  Jan-08
# 2                 217437       0.4305  Jan-08
# 3                 230237       0.4180  Jan-08
# 4                 239404       0.3794  Jan-08
# ...                  ...          ...     ...
# 3294              838079       0.0892  Apr-21
# 3295             1779639       0.0865  Apr-21
# 3296             1342353       0.1203  Apr-21
# 3297             1304895       0.0942  Apr-21
# 3298             3514692       0.2789  Apr-21
#
# [3299 rows x 16 columns]

# %% [markdown]
# ## Visual and programmatic Assesment

# %%
#Check the shape of data
stock.shape
# Out:
# (3299, 16)

# %% [markdown]
# ###### The dataset has 3299 rows and 16 columns

# %%
#check the column info and information
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3299 entries, 0 to 3298
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                3299 non-null   object
#  1   Symbol              3299 non-null   object
#  2   Series              3299 non-null   object
#  3   Prev Close          3299 non-null   float64
#  4   Open                3299 non-null   float64
#  5   High                3299 non-null   float64
#  6   Low                 3299 non-null   float64
#  7   Last                3299 non-null   float64
#  8   Close               3299 non-null   float64
#  9   VWAP                3299 non-null   float64
#  10  Volume              3299 non-null   int64
#  11  Turnover            3299 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  3299 non-null   int64
#  14  %Deliverble         3299 non-null   float64
#  15  M.Y                 3299 non-null   object
# dtypes: float64(10), int64(2), object(4)
# memory usage: 412.5+ KB

# %% [markdown]
# ###### From the above dataset has the following issuses

# %% [markdown]
# * Missing/ Null Values

# %% [markdown]
# Trades

# %%
#Dropping the unneccessary column

stocks=stock.drop(['Trades','%Deliverble','Series','Prev Close'],axis='columns')

# %%
stocks
# Out:
#             Date      Symbol     Open     High      Low     Last    Close  \
# 0     01-01-2008  MUNDRAPORT  1279.00  1319.00  1263.70  1308.00  1296.85
# 1     02-01-2008  MUNDRAPORT  1310.25  1324.00  1270.00  1300.15  1307.45
# 2     03-01-2008  MUNDRAPORT  1305.00  1314.70  1261.15  1267.15  1275.80
# 3     04-01-2008  MUNDRAPORT  1278.80  1294.80  1233.00  1239.90  1240.35
# 4     07-01-2008  MUNDRAPORT  1240.00  1278.90  1215.00  1233.00  1227.25
# ...          ...         ...      ...      ...      ...      ...      ...
# 3294  26-04-2021  ADANIPORTS   733.00   739.65   728.90   729.20   730.75
# 3295  27-04-2021  ADANIPORTS   735.00   757.50   727.35   748.60   749.15
# 3296  28-04-2021  ADANIPORTS   755.00   760.00   741.10   743.40   746.25
# 3297  29-04-2021  ADANIPORTS   753.20   765.85   743.40   746.40   746.75
# 3298  30-04-2021  ADANIPORTS   739.00   759.45   724.50   726.40   730.05
#
#          VWAP    Volume      Turnover  Deliverable Volume     M.Y
# 0     1285.72    491348  6.317350e+13              172911  Jan-08
# 1     1302.15    703815  9.164730e+13              221397  Jan-08
# 2     1289.24    505058  6.511430e+13              217437  Jan-08
# 3     1256.03    550795  6.918170e+13              230237  Jan-08
# 4     1244.76    630963  7.853980e+13              239404  Jan-08
# ...       ...       ...           ...                 ...     ...
# 3294   733.25   9390549  6.885660e+14              838079  Apr-21
# 3295   747.67  20573107  1.538190e+15             1779639  Apr-21
# 3296   751.02  11156977  8.379110e+14             1342353  Apr-21
# 3297   753.06  13851910  1.043140e+15             1304895  Apr-21
# 3298   743.35  12600934  9.366910e+14             3514692  Apr-21
#
# [3299 rows x 12 columns]

# %%
#Change the datatype
stocks['Date']=pd.to_datetime(stocks['Date'])
stocks
# Out:
#            Date      Symbol     Open     High      Low     Last    Close  \
# 0    2008-01-01  MUNDRAPORT  1279.00  1319.00  1263.70  1308.00  1296.85
# 1    2008-02-01  MUNDRAPORT  1310.25  1324.00  1270.00  1300.15  1307.45
# 2    2008-03-01  MUNDRAPORT  1305.00  1314.70  1261.15  1267.15  1275.80
# 3    2008-04-01  MUNDRAPORT  1278.80  1294.80  1233.00  1239.90  1240.35
# 4    2008-07-01  MUNDRAPORT  1240.00  1278.90  1215.00  1233.00  1227.25
# ...         ...         ...      ...      ...      ...      ...      ...
# 3294 2021-04-26  ADANIPORTS   733.00   739.65   728.90   729.20   730.75
# 3295 2021-04-27  ADANIPORTS   735.00   757.50   727.35   748.60   749.15
# 3296 2021-04-28  ADANIPORTS   755.00   760.00   741.10   743.40   746.25
# 3297 2021-04-29  ADANIPORTS   753.20   765.85   743.40   746.40   746.75
# 3298 2021-04-30  ADANIPORTS   739.00   759.45   724.50   726.40   730.05
#
#          VWAP    Volume      Turnover  Deliverable Volume     M.Y  \
# 0     1285.72    491348  6.317350e+13              172911  Jan-08
# 1     1302.15    703815  9.164730e+13              221397  Jan-08
# 2     1289.24    505058  6.511430e+13              217437  Jan-08
# 3     1256.03    550795  6.918170e+13              230237  Jan-08
# 4     1244.76    630963  7.853980e+13              239404  Jan-08
# ...       ...       ...           ...                 ...     ...
# 3294   733.25   9390549  6.885660e+14              838079  Apr-21
# 3295   747.67  20573107  1.538190e+15             1779639  Apr-21
# 3296   751.02  11156977  8.379110e+14             1342353  Apr-21
# 3297   753.06  13851910  1.043140e+15             1304895  Apr-21
# 3298   743.35  12600934  9.366910e+14             3514692  Apr-21
#
#       Intraday Volume
# 0              318437
# 1              482418
# 2              287621
# 3              320558
# 4              391559
# ...               ...
# 3294          8552470
# 3295         18793468
# 3296          9814624
# 3297         12547015
# 3298          9086242
#
# [3299 rows x 13 columns]

# %%
#view the dataset
stocks
# Out:
#            Date      Symbol     Open     High      Low     Last    Close  \
# 0    2008-01-01  MUNDRAPORT  1279.00  1319.00  1263.70  1308.00  1296.85
# 1    2008-02-01  MUNDRAPORT  1310.25  1324.00  1270.00  1300.15  1307.45
# 2    2008-03-01  MUNDRAPORT  1305.00  1314.70  1261.15  1267.15  1275.80
# 3    2008-04-01  MUNDRAPORT  1278.80  1294.80  1233.00  1239.90  1240.35
# 4    2008-07-01  MUNDRAPORT  1240.00  1278.90  1215.00  1233.00  1227.25
# ...         ...         ...      ...      ...      ...      ...      ...
# 3294 2021-04-26  ADANIPORTS   733.00   739.65   728.90   729.20   730.75
# 3295 2021-04-27  ADANIPORTS   735.00   757.50   727.35   748.60   749.15
# 3296 2021-04-28  ADANIPORTS   755.00   760.00   741.10   743.40   746.25
# 3297 2021-04-29  ADANIPORTS   753.20   765.85   743.40   746.40   746.75
# 3298 2021-04-30  ADANIPORTS   739.00   759.45   724.50   726.40   730.05
#
#          VWAP    Volume      Turnover  Deliverable Volume     M.Y
# 0     1285.72    491348  6.317350e+13              172911  Jan-08
# 1     1302.15    703815  9.164730e+13              221397  Jan-08
# 2     1289.24    505058  6.511430e+13              217437  Jan-08
# 3     1256.03    550795  6.918170e+13              230237  Jan-08
# 4     1244.76    630963  7.853980e+13              239404  Jan-08
# ...       ...       ...           ...                 ...     ...
# 3294   733.25   9390549  6.885660e+14              838079  Apr-21
# 3295   747.67  20573107  1.538190e+15             1779639  Apr-21
# 3296   751.02  11156977  8.379110e+14             1342353  Apr-21
# 3297   753.06  13851910  1.043140e+15             1304895  Apr-21
# 3298   743.35  12600934  9.366910e+14             3514692  Apr-21
#
# [3299 rows x 12 columns]

# %%
#Check the null values in the dataset
stocks.isnull().sum()
# Out:
# Date                  0
# Symbol                0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Deliverable Volume    0
# M.Y                   0
# dtype: int64

# %% [markdown]
# *After fixing the missing values , will drop the columns that is not using this project

# %%
#After cleaning data check the info of table
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3299 entries, 0 to 3298
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                3299 non-null   datetime64[ns]
#  1   Symbol              3299 non-null   object
#  2   Open                3299 non-null   float64
#  3   High                3299 non-null   float64
#  4   Low                 3299 non-null   float64
#  5   Last                3299 non-null   float64
#  6   Close               3299 non-null   float64
#  7   VWAP                3299 non-null   float64
#  8   Volume              3299 non-null   int64
#  9   Turnover            3299 non-null   float64
#  10  Deliverable Volume  3299 non-null   int64
#  11  M.Y                 3299 non-null   object
# dtypes: datetime64[ns](1), float64(7), int64(2), object(2)
# memory usage: 309.4+ KB

# %%
#check the dimension of the table
stocks.shape
# Out:
# (3299, 12)

# %% [markdown]
# *Saving a copy of  cleaned data

# %%
#save the data
stocks.to_csv('stocks.csv',index=False)

# %% [markdown]
# *Here i am using another one data , that is called Metadata the dataset shows the different sectors in the stock market
# and what are the companies investing in which sector

# %%
#load the dataset
metadata=pd.read_csv('stock_metadata.csv')

# %%
#view the dataset
metadata.head(5)
# Out:
#                                  Company Name            Industry      Symbol  \
# 0  Adani Ports and Special Economic Zone Ltd.            SERVICES  ADANIPORTS
# 1                           Asian Paints Ltd.      CONSUMER GOODS  ASIANPAINT
# 2                              Axis Bank Ltd.  FINANCIAL SERVICES    AXISBANK
# 3                             Bajaj Auto Ltd.          AUTOMOBILE  BAJAJ-AUTO
# 4                          Bajaj Finserv Ltd.  FINANCIAL SERVICES  BAJAJFINSV
#
#   Series     ISIN Code
# 0     EQ  INE742F01042
# 1     EQ  INE021A01026
# 2     EQ  INE238A01034
# 3     EQ  INE917I01010
# 4     EQ  INE918I01018

# %%
#check the dimension of the table
metadata.shape
# Out:
# (50, 5)

# %%
#drop the unnecssary columns
metadatas=metadata.drop(['Series','ISIN Code'],axis='columns')

# %%
#view the dataset
metadatas
# Out:
#                                     Company Name                  Industry  \
# 0     Adani Ports and Special Economic Zone Ltd.                  SERVICES
# 1                              Asian Paints Ltd.            CONSUMER GOODS
# 2                                 Axis Bank Ltd.        FINANCIAL SERVICES
# 3                                Bajaj Auto Ltd.                AUTOMOBILE
# 4                             Bajaj Finserv Ltd.        FINANCIAL SERVICES
# 5                             Bajaj Finance Ltd.        FINANCIAL SERVICES
# 6                             Bharti Airtel Ltd.                   TELECOM
# 7              Bharat Petroleum Corporation Ltd.                    ENERGY
# 8                      Britannia Industries Ltd.            CONSUMER GOODS
# 9                                     Cipla Ltd.                    PHARMA
# 10                               Coal India Ltd.                    METALS
# 11                 Dr. Reddy's Laboratories Ltd.                    PHARMA
# 12                            Eicher Motors Ltd.                AUTOMOBILE
# 41   TATASTEEL
# 42         TCS
# 43       TECHM
# 44       TITAN
# 45  ULTRACEMCO
# 46         UPL
# 47        VEDL
# 48       WIPRO
# 49        ZEEL

# %% [markdown]
# ## Questions

# %% [markdown]
# 1.Which Companies are investing Which Sector Stocks

# %% [markdown]
# 2.Display industry sectors and Companys

# %% [markdown]
# 3.Plot the graph to Visualize the Trending Price of Adani Port Stock

# %% [markdown]
# 4.Plot 100 Days moving Average

# %% [markdown]
# 5.Plot the difference between 100 and 200 Days moving Average

# %% [markdown]
# 6.Adani port Volume of trade in 2008-2021

# %% [markdown]
# 7.Find the average of High,Low,Open,Close in 2019-2021

# %% [markdown]
# 8.check which day adani port trade max trading volume

# %% [markdown]
# 9.Find the Intraday Volume of Trade Per Day

# %% [markdown]
# 10.plot Different types of volume trades in adani stocks

# %% [markdown]
# 11.Top 5 high volume trades in adani stocks

# %% [markdown]
# 12.Find the average monthly Open of adani Port

# %% [markdown]
# 13.Finding Last Business day for every month

# %% [markdown]
# 14.Get the last business day of each Quarter from April-2019

# %% [markdown]
# ## Exploration

# %% [markdown]
# ### Which Companies are investing Which Sector Stocks?

# %%
plt.figure(figsize=(16,6))
sns.countplot(metadatas['Industry'],color="b")
plt.title('Sector Wise Companies investing')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\vsury\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Majority of the sector is Financial Services and Energy sector ,
# Most of the MNC's are investing these two sectors

# %% [markdown]
# There are 13 sectors in Nifty-50 Stocks
#
# The top trading companies are listed in Each Sector
#
# So that We have a good understanding idea to invest our money in  which sector

# %% [markdown]
# ### Display industry sectors and Companys

# %%
ab=metadatas.iloc[:,[1,0]]
ab.sort_values(by='Industry')
# Out:
#                     Industry                                  Company Name
# 18                AUTOMOBILE                            Hero MotoCorp Ltd.
# 30                AUTOMOBILE                      Mahindra & Mahindra Ltd.
# 31                AUTOMOBILE                      Maruti Suzuki India Ltd.
# 40                AUTOMOBILE                              Tata Motors Ltd.
# 12                AUTOMOBILE                            Eicher Motors Ltd.
# 3                 AUTOMOBILE                               Bajaj Auto Ltd.
# 14  CEMENT & CEMENT PRODUCTS                        Grasim Industries Ltd.
# 38  CEMENT & CEMENT PRODUCTS                             Shree Cement Ltd.
# 45  CEMENT & CEMENT PRODUCTS                         UltraTech Cement Ltd.
# 29              CONSTRUCTION                          Larsen & Toubro Ltd.
# 26            CONSUMER GOODS                                      ITC Ltd.
# 8             CONSUMER GOODS                     Britannia Industries Ltd.
# 44            CONSUMER GOODS                            Titan Company Ltd.
# 32            CONSUMER GOODS                             Nestle India Ltd.
# 20            CONSUMER GOODS                       Hindustan Unilever Ltd.
# 1             CONSUMER GOODS                             Asian Paints Ltd.
# 36                    ENERGY                      Reliance Industries Ltd.
# 33                    ENERGY                                     NTPC Ltd.
# 34                    ENERGY            Oil & Natural Gas Corporation Ltd.
# 13                    ENERGY                             GAIL (India) Ltd.
# 7                     ENERGY             Bharat Petroleum Corporation Ltd.
# 35                    ENERGY          Power Grid Corporation of India Ltd.
# 25                    ENERGY                   Indian Oil Corporation Ltd.
# 46  FERTILISERS & PESTICIDES                                      UPL Ltd.
# 28        FINANCIAL SERVICES                      Kotak Mahindra Bank Ltd.
# 37        FINANCIAL SERVICES                           State Bank of India
# 22        FINANCIAL SERVICES                            IndusInd Bank Ltd.
# 21        FINANCIAL SERVICES                               ICICI Bank Ltd.
# 17        FINANCIAL SERVICES                                HDFC Bank Ltd.
# 16        FINANCIAL SERVICES  Housing Development Finance Corporation Ltd.
# 5         FINANCIAL SERVICES                            Bajaj Finance Ltd.
# 4         FINANCIAL SERVICES                            Bajaj Finserv Ltd.
# 2         FINANCIAL SERVICES                                Axis Bank Ltd.
# 42                        IT                Tata Consultancy Services Ltd.
# 15                        IT                         HCL Technologies Ltd.
# 43                        IT                            Tech Mahindra Ltd.
# 48                        IT                                    Wipro Ltd.
# 24                        IT                                  Infosys Ltd.
# 49     MEDIA & ENTERTAINMENT            Zee Entertainment Enterprises Ltd.
# 41                    METALS                               Tata Steel Ltd.
# 19                    METALS                      Hindalco Industries Ltd.
# 10                    METALS                               Coal India Ltd.
# 47                    METALS                                  Vedanta Ltd.
# 27                    METALS                                JSW Steel Ltd.
# 39                    PHARMA            Sun Pharmaceutical Industries Ltd.
# 11                    PHARMA                 Dr. Reddy's Laboratories Ltd.
# 9                     PHARMA                                    Cipla Ltd.
# 0                   SERVICES    Adani Ports and Special Economic Zone Ltd.
# 23                   TELECOM                          Bharti Infratel Ltd.
# 6                    TELECOM                            Bharti Airtel Ltd.

# %% [markdown]
# ### Plot the graph to Visualize the Trending Price of Adani Port Stock

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(17,15))

# Plot open price on first subplot
stocks.plot(ax=ax1, x='Date', y='Open', color='g')
ax1.set_xlabel("Date")
ax1.set_ylabel("Price range")
ax1.set_title("Open VS Date")

# Plot close price on second subplot
stocks.plot(ax=ax2, x='Date', y='Close', color='r')
ax2.set_xlabel("Date")
ax2.set_ylabel("Price range")
ax2.set_title("Close VS Date")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plot 100 Days moving Average

# %%
    #use rolling command into take the 100 days average value 
ma100=stocks.Open.rolling(100).mean()

# %%
#View
ma100
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 3294    602.1925
# 3295    605.5345
# 3296    608.9745
# 3297    612.3565
# 3298    615.4975
# Name: Open, Length: 3299, dtype: float64

# %% [markdown]
# This is showing first 100 values as NAN values after that it takes the avearage of every 100 to 100.

# %%
plt.figure(figsize=(15,10))
plt.plot(stocks.Open,label="Open")
plt.plot(ma100,label="ma100")
plt.legend()
plt.show()

# %% [markdown]
# Importance of a 100-day Moving Average A moving average over 100 days helps investors see how the stock has performed over 20 weeks and to find the price trend if it is upward or downward

# %% [markdown]
# ### Plot the difference between 100 and 200 Days moving Average

# %%
#Plot-the-difference-between-100-and-200-Days-moving-Average 
ma200=stocks.Open.rolling(200).mean()

# %%
#view the data
ma200
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 3294    475.02825
# 3295    476.95825
# 3296    479.02825
# 3297    481.08925
# 3298    483.10300
# Name: Open, Length: 3299, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.plot(stocks.Open,label="Open")
plt.plot(ma100,label="ma100")
plt.plot(ma200,label="ma200")
plt.title('Difference between 100 and 200 Days moving Average')
plt.legend()
plt.show()

# %% [markdown]
# The difference between a 100-day moving average and a 200-day moving average is the amount of data that is being used to calculate the average. Because the 200-day moving average is based on twice as much data as the 100-day moving average, it will be less sensitive to short-term fluctuations and changes in the stock's price. It is considered as a long-term indicator, looking at the average trend of price over a longer period.

# %% [markdown]
# ### Adani port Volume of trade in 2008-2021

# %%
#create a Duplicate dataset
stocksdate=stocks

# %%
#Assign the start date and end date to these variable and access
start_date = "2019-04-30"
end_date = "2021-04-30"
mask=(stocksdate["Date"] >= start_date) & (stocksdate["Date"] <= end_date)
stocksdate=stocksdate.loc[mask]

# %%
plt.figure(figsize=(15,8))
plt.plot(stocksdate['Volume'])
plt.title("Adani port Volume of trade in 2019-2021")
plt.ylabel('Volume in Crores')
plt.show()

# %%
max_volume=max(stocksdate['Volume'])
max_row=stocksdate.loc[stocksdate['Volume'] == max_volume]
max_row
# Out:
#            Date      Symbol   Open    High     Low   Last   Close    VWAP  \
# 3287 2021-04-13  ADANIPORTS  750.0  755.75  701.35  733.1  731.05  723.89
#
#         Volume      Turnover  Deliverable Volume     M.Y
# 3287  52812517  3.823030e+15             8937704  Apr-21

# %% [markdown]
# The Volume of trade happend in the adani ports between 2008- 2021 . The Highest Volume of trade is 5.2 Crore Volume Trade is this day and the date is 13 April 2021

# %% [markdown]
# ### Find the average of High,Low,Open,Close in 2019-2021

# %%
#find the average 
avghigh=stocksdate["High"].mean()
avglow=stocksdate["Low"].mean()
avgopen=stocksdate["Open"].mean()
avgclose=stocksdate["Close"].mean()

print("Adani Port Average high:",avghigh,
      "\nAdani Port Average Low:",avglow,
      "\nAdani Port Average Open:",avgopen,
      "\nAdani Port Average Close:",avgclose)
# Out:
# Adani Port Average high: 403.287421383648
# Adani Port Average Low: 389.80922431865855
# Adani Port Average Open: 396.83899371069174
# Adani Port Average Close: 396.69748427672914

# %% [markdown]
# ### Find the Intraday Volume of Trade Per Day

# %%
#To find the intraday volume is to subtract the Volume into Deliverable Volume
stocks["Intraday Volume"]=stocks['Volume']-stocks["Deliverable Volume"]
stocks.head()
# Out:
#         Date      Symbol     Open    High      Low     Last    Close     VWAP  \
# 0 2008-01-01  MUNDRAPORT  1279.00  1319.0  1263.70  1308.00  1296.85  1285.72
# 1 2008-02-01  MUNDRAPORT  1310.25  1324.0  1270.00  1300.15  1307.45  1302.15
# 2 2008-03-01  MUNDRAPORT  1305.00  1314.7  1261.15  1267.15  1275.80  1289.24
# 3 2008-04-01  MUNDRAPORT  1278.80  1294.8  1233.00  1239.90  1240.35  1256.03
# 4 2008-07-01  MUNDRAPORT  1240.00  1278.9  1215.00  1233.00  1227.25  1244.76
#
#    Volume      Turnover  Deliverable Volume     M.Y  Intraday Volume
# 0  491348  6.317350e+13              172911  Jan-08           318437
# 1  703815  9.164730e+13              221397  Jan-08           482418
# 2  505058  6.511430e+13              217437  Jan-08           287621
# 3  550795  6.918170e+13              230237  Jan-08           320558
# 4  630963  7.853980e+13              239404  Jan-08           391559

# %% [markdown]
# In this Process i add one column to find the intraday volume of trade

# %% [markdown]
# ### Plot Different types of volume trades in adani stocks

# %%
#Plot the Piechart
plt.figure(figsize=(8,8))
DVIV=["Deliverable Volume","Intraday Volume"]
piechart=stocks["Deliverable Volume"].sum(),stocks["Intraday Volume"].sum()
plt.pie(piechart,labels=DVIV,autopct="%1.2f%%")
plt.title("Types of Volumes in Adani Port Stocks")
plt.show()

# %% [markdown]
# In this Pie chart Display the deliverable volume and intraday volume of trade per day the most of the people are doing intraday trading only, so adani port stock is more volatile so most of all investing intraday Volume

# %% [markdown]
# ### Top 5 high volume trades in adani stocks

# %%
Top_5=stocks.sort_values(by="Volume",ascending=False)
Top_5.head()
# Out:
#            Date      Symbol   Open    High     Low    Last   Close    VWAP  \
# 3283 2021-07-04  ADANIPORTS  857.0  885.00  795.00  812.45  814.75  835.16
# 3282 2021-06-04  ADANIPORTS  756.0  852.70  743.00  849.85  835.55  800.35
# 3287 2021-04-13  ADANIPORTS  750.0  755.75  701.35  733.10  731.05  723.89
# 3289 2021-04-16  ADANIPORTS  750.9  794.85  743.00  749.15  755.50  770.01
# 3251 2021-02-17  ADANIPORTS  658.0  670.00  646.90  654.00  655.75  658.20
#
#         Volume      Turnover  Deliverable Volume     M.Y  Intraday Volume
# 3283  97717880  8.160990e+15             8025095  Apr-21         89692785
# 3282  64555516  5.166680e+15             4484783  Apr-21         60070733
# 3287  52812517  3.823030e+15             8937704  Apr-21         43874813
# 3289  41791181  3.217940e+15             3455564  Apr-21         38335617
# 3251  34868085  2.295020e+15             6455210  Feb-21         28412875

# %% [markdown]
# ### Find the average monthly Open of adani Port

# %%
#Assume new Variable
stockdates=stocksdate
stockdates=stockdates.set_index('Date')
stockavg.head()
# Out:
#                 Symbol     Open    High      Low     Last    Close     VWAP  \
# Date
# 2008-01-01  MUNDRAPORT  1279.00  1319.0  1263.70  1308.00  1296.85  1285.72
# 2008-02-01  MUNDRAPORT  1310.25  1324.0  1270.00  1300.15  1307.45  1302.15
# 2008-03-01  MUNDRAPORT  1305.00  1314.7  1261.15  1267.15  1275.80  1289.24
# 2008-04-01  MUNDRAPORT  1278.80  1294.8  1233.00  1239.90  1240.35  1256.03
# 2008-07-01  MUNDRAPORT  1240.00  1278.9  1215.00  1233.00  1227.25  1244.76
#
#             Volume      Turnover  Deliverable Volume     M.Y  Intraday Volume
# Date
# 2008-01-01  491348  6.317350e+13              172911  Jan-08           318437
# 2008-02-01  703815  9.164730e+13              221397  Jan-08           482418
# 2008-03-01  505058  6.511430e+13              217437  Jan-08           287621
# 2008-04-01  550795  6.918170e+13              230237  Jan-08           320558
# 2008-07-01  630963  7.853980e+13              239404  Jan-08           391559

# %%
stockdates.Open.resample("M").mean()
# Out:
# Date
# 2019-04-30    391.150000
# 2019-05-31    384.502174
# 2019-06-30    397.325000
